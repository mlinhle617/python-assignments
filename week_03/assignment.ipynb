# %%
poem = "The Naming of Cats"
author = "T. S. Eliot"

print(poem)
print("by " + author)
print("\n")

print(poem + " is a difficult matter,")

poem_lines = {
    'line 1' : 'It isn’t just one of your holiday games;',
    'line 2' : 'You may think at first I’m as mad as a hatter',
    }

for value in poem_lines.values():
    print(value)

def printNames(name_list):
    for name in name_list:
        print(name + ", ")

names = [family_names, fancier_names, peculiar_names]
words = ("different", "names")
print("When I tell you, a cat must have " + str(len(names)) + " " + words[0].upper() + " " + words[1].upper() + ".")

poem_lines.update({'line 3' : 'First of all, there’s the name that the family use daily,'})
print(poem_lines['line 3'])

family_names = ["Peter", "Augustus", "Alonzo", "James"]

print("Such as ")

printNames(family_names)
family_names.append("Victor")
family_names.append("Jonathan")
family_names.append("George")
family_names.append("Bill Bailey")
print("Such as " + family_names[4] + " or " + family_names[5] + ", " + family_names[6] + " or " + family_names[7] + "—")

poem_lines['line 4'] = 'All of them sensible everyday names.'
print(poem_lines.get('line 4'))

x = "you think they sound sweeter"
if x:
    print("There are fancier names" + " if " + x + ",")
    
print("Some for the gentlemen, some for the dames:")

fancier_names = ["Plato", "Admetus", "Electra", "Demeter"]
print("Such as " + fancier_names[0] + ", " + fancier_names[1] + ", " + fancier_names[2] + ", " + fancier_names[3] + "—")

line_5 = "But all of them sensible everyday names,"
print(line_5.split(' '))

def printLines(dict):
    for key, value in dict.items():
        print(key + " " + value)
        
poem_lines_2 = {
    'But I tell you,' : 'a cat needs a name that’s particular,',
    'A name that’s peculiar,' : 'and more dignified,',
    'Else how can he keep up' : 'his tail perpendicular,',
    'Or spread out his whiskers,' : 'or cherish his pride?',
    'Of names of this kind,' : 'I can give you a quorum,'
    }

printLines(poem_lines_2)
    
peculiar_names = ["Munkustrap", "Quaxo", "Coricopat"]
print("Such as " + peculiar_names[0] + ", " + peculiar_names[1] + ", or " + peculiar_names[2] + ", ")
peculiar_names_2 = ["Bombalurina", "Jellylorum"]
peculiar_names.extend(peculiar_names_2)
print("Such as " + peculiar_names[3] + ", or else ")
print(peculiar_names.pop(4) + "—")

poem_lines_3 = {
    'Names that never belong' : 'to more than one cat.',
    'But above and beyond' : 'there’s still one name left over,',
    'And that is the name' : 'that you never will guess;',
    'The name that' : 'no human research can discover—',
    'But THE CAT HIMSELF KNOWS,' : 'and will never confess.'
    }

printLines(poem_lines_3)

x = 1
while x <= 1:
    print("When you notice a cat in profound meditation,")
    x += 1 
else: 
    print("The reason, I tell you, is always the same:")

print("His mind is engaged in a rapt contemplation")
print("Of the thought, of the thought, of the thought of his name:")
print("His ineffable effable")

for letter in 'Effanineffable':
    print(letter)

print("Deep and inscrutable singular name.")
# Out:
# The Naming of Cats
# by T. S. Eliot
#
#
# The Naming of Cats is a difficult matter,
# It isn’t just one of your holiday games;
# You may think at first I’m as mad as a hatter
# When I tell you, a cat must have 3 DIFFERENT NAMES.
# First of all, there’s the name that the family use daily,
# Such as
# Peter,
# Augustus,
# Alonzo,
# James,
# Such as Victor or Jonathan, George or Bill Bailey—
# All of them sensible everyday names.
# There are fancier names if you think they sound sweeter,
# Some for the gentlemen, some for the dames:
# Such as Plato, Admetus, Electra, Demeter—
# ['But', 'all', 'of', 'them', 'sensible', 'everyday', 'names,']
# But I tell you, a cat needs a name that’s particular,
# A name that’s peculiar, and more dignified,
# Else how can he keep up his tail perpendicular,
# Or spread out his whiskers, or cherish his pride?
# Of names of this kind, I can give you a quorum,
# Such as Munkustrap, Quaxo, or Coricopat,
# Such as Bombalurina, or else
# Jellylorum—
# Names that never belong to more than one cat.
# But above and beyond there’s still one name left over,
# And that is the name that you never will guess;
# The name that no human research can discover—
# But THE CAT HIMSELF KNOWS, and will never confess.
# When you notice a cat in profound meditation,
# The reason, I tell you, is always the same:
# His mind is engaged in a rapt contemplation
# Of the thought, of the thought, of the thought of his name:
# His ineffable effable
# E
# f
# f
# a
# n
# i
# n
# e
# f
# f
# a
# b
# l
# e
# Deep and inscrutable singular name.
